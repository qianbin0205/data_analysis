# %%
import re
import time
from meituan_tools import Operation
import pandas as pd
import pyecharts

# %%
# 数据库连接
op = Operation()
conn = op.db_conn()
cur = conn.cursor()

# %% [markdown]
# **拿到数据先整体数值字段max,min看下异常数据，这些极值会影响最后统计结果**
#
# **里面发现有很多数据人均价格和评分是0的，在这里我们需要这些数据进行剔除**

# %%
# 数据检查
sql = '''	select distinct 
	b.poi_id,b.title,b.avg_price,b.avg_score,b.comment_num,b.address from meituan_classify_info as a
	inner join meituan_shop_info as b on a.sub_id = b.sub_id and a.class_type = b.class_type
	where a.class_type = 1 and a.sub_id not in(24,393,395) and b.avg_price <> 0 and b.avg_score <> 0
	order by avg_price desc'''

df = pd.read_sql(sql,conn,index_col=['poi_id'])
df
# Out:
#                           title  avg_price  avg_score  comment_num  \
# poi_id
# 162761320                   黄公子     2665.0        5.0            7
# 2718768           十里洋场江景会所（外滩店）     1489.0        4.0            0
# 1578636                  MOOK酒吧     1044.0        5.0           51
# 1580796                    浦江二号      994.0        5.0            2
# 476286                   菲芘3d酒吧      902.0        4.0           19
# 2473301              洋房火锅（新天地店）      901.0        5.0          509
# 158735513    本色TureColor酒吧（外滩店）      846.0        5.0           60
# 454005                   宏豪浦江一号      816.0        5.0            5
# 40673951           原烹（金虹桥国际中心店）      790.0        5.0            3
# 2730725                     花籠味      768.0        4.5            0
# 6112293                     香然会      723.0        4.5            0
# 159436207        FEELING CLUB酒吧      685.0        5.0           82
# 64049059               榭福屋（静安店）      661.0        4.5            0
# 1607949               晓芹海参（鲁班店）      655.0        3.5            0
# 91906668                    浦江荟      635.0        5.0            6
# 81256882   TheMEAT∙扒餐厅（浦东嘉里大酒店）      616.0        4.0            0
# 83259397              晓芹海参（长宁店）      590.0        3.5            0
# 138245571          蟹的岡田屋（尚嘉中心店）      575.0        4.4            8
# 403296        翡翠36餐厅（浦东香格里拉大酒店）      570.0        3.8           10
# 106050874           SKY酒吧（同乐坊店）      567.0        5.0          385
# 394974          珍御轩（新加坡泰国村鱼翅酒楼）      562.0        4.0            1
# 2661742             外滩悦榕庄-酩缘中餐厅      561.0        3.5            0
# 4973672       MT 1839 Club（闵行店）      551.0        3.9           13
# 2421173             世博源公馆（世博源店）      550.0        4.7          119
# 107503900          蟹的岡田屋（正大广场店）      549.0        4.0           19
# 163519766           伙房水产（陆家嘴总店）      545.0        5.0            1
# 155992192         蟹的岡田屋（绿地缤纷城店）      530.0        4.0           10
# 5153889             外滩悦榕庄-海怡西餐厅      527.0        3.9           17
# 5340006               龙一海鲜（普陀店）      523.0        4.0            7
# 42127593                BM101酒吧      509.0        4.8          539
# ...                         ...        ...        ...          ...
# 89590945        吉合烤饼（嘉杰国际商业广场店）        9.0        4.3          339
# 41396641              鸡翅包饭（松江店）        9.0        4.0         7573
# 2410561            超级奶爸（江桥沃尔玛店）        9.0        4.1         1085
# 106050874                             静安区余姚路74号靠近海防路路口（同乐坊内）
# 394974                                     杨浦区国定东路237号（近翔殷路）
# 2661742                           虹口区海平路19号上海外滩悦榕庄酒店2楼（公平路口）
# 4973672                            闵行区七莘路1839号财富108广场5楼（顾戴路）
# 2421173                         浦东新区世博大道1368号世博源1区L2层L201-02
# 107503900                   浦东新区陆家嘴西路168号正大广场西区5层26B号（近东方明珠）
# 163519766                         浦东新区东方路778号紫金山大酒店2楼（近世纪大道）
# 155992192  徐汇区瑞平路88号绿地缤纷城1层W-D106、107（地铁龙华中路站5、6、7号出口，靠近东安路）
# 5153889                           虹口区海平路19号鹏欣外滩悦榕庄酒店一楼（公平路口）
# 5340006                                         宝山区古浪路55弄11号
# 42127593                               浦东新区南泉北路528号（新大陆广场3F）
# ...                                                      ...
# 89590945                             虹口区四川北路1727弄嘉杰国际商业广场B1层
# 41396641                                     松江区庙前街54号（侍衣派旁）
# 2410561                             嘉定区曹安公路2118号1030室（沃尔玛一楼）
# 96769827                                  嘉定区博乐路与嘉定东大街交叉口西北角
# 41356582                                浦东新区南汇镇东门大街77号（光明医院）
# 78705706               闵行区华新镇新府中路1536号宝龙城市广场1楼020室（如海、好药师旁边）
# 99356478                       嘉定区江桥镇曹安公路2118号沃尔玛一楼（亚一金店入口处）
# 5415000                                  堡镇堡镇中路153号（渝一锅火锅对面）
# 5949468                                  南门城桥镇新崇南路219号（肯德基旁）
# 74268107                              嘉定区华江路850弄17号（万达金街17号）
# 4441687                               浦东新区民耀路422号1楼（悸动烧仙草旁边）
# 41461534                                      奉贤区南桥镇环城南路935号
# 42067538                         青浦区绿港购物广场105室（SomeCoffee下面）
# 84978808                           青浦区赵重公路2778弄81号（现代华庭小区出口）
# 115394563                                         青浦区青湖路899号
# 98142819                                      金山区兴塔镇新金山路289号
# 82035969                                       青浦区崧文南路169弄3号
# 435280                                             松江区庙前街54号
# 94145441                              松江区玉树路2581-2583号飞航广场1层
# 73651050                                          黄浦区天津路159号
# 94186511                                宝山区牡丹江路1599号北翼商业街F1号
# 100932130                                    青浦区庆华一路北门街3号15弄
# 69767825                                 松江区庙前街98号（周黑鸭同一个门面）
# 88196929                         浦东新区川沙新镇新德西路100弄101号（地纬广场内）
# 42283206                                         松江区横港公路638号
# 111135929              长兴岛长兴镇凤凰镇丰福路599弄金滂路178号109室近月牙港路久久鸭旁边
# 383698                              长宁区玉屏南路340弄（玉屏南路与遵义路交汇处）
# 83019020                                          嘉定区南大街131号
# 41851753                                          松江区庙前街105号
# 94594765                                   松江区庙前街二十三号（沃尔玛旁边）
#
# [8003 rows x 5 columns]

# %% [markdown]
# **对人均降序排序后，发现最贵的是“黄公子”人均2665，不由得让我们对前10的商家起了兴趣，于是上了百度查看了一下**

# %%
df = df.head(10)
title = df['title']
avg_price =  df['avg_price']
avg_score = df['avg_score']
comment_num = df['comment_num']

from pyecharts import Bar,Grid

bar = Bar(title="餐饮商家前十排行",subtitle='数据来源美*',width=800,height=400)
bar.add("人均", title, avg_price, mark_point=["min", "max"],mark_line=["average"],is_label_show=True)
bar.add("评论数", title, comment_num,is_label_show=True, xaxis_rotate=30)

grid = Grid()
grid.add(bar, grid_bottom="30%")

grid
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min'
#         }
#     });
# </script>
#     <div id="c97611fb1e654d06969065df5498ff4b" style="width:800px;height:400px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#
# var myChart_c97611fb1e654d06969065df5498ff4b = echarts.init(document.getElementById('c97611fb1e654d06969065df5498ff4b'), null, {renderer: 'canvas'});
# var option_c97611fb1e654d06969065df5498ff4b = {
#     "yAxis": [
#         {
#             "nameLocation": "middle",
#             "min": null,
#             "splitLine": {
#                 "show": true
#             },
#             "show": true,
#             "position": null,
#             "axisLabel": {
#                 "margin": 8,
#                 "interval": "auto",
#                 "formatter": "{value} ",
#                 "rotate": 0,
#                 "textStyle": {
#                     "fontSize": 12,
#                     "color": "#000"
#                 }
#             },
#             "boundaryGap": true,
#             "name": "",
#             "nameTextStyle": {
#                 "fontSize": 14
#             },
#             "nameGap": 25,
#             "inverse": false,
#             "max": null,
#             "type": "value",
#             "axisTick": {
#                 "alignWithLabel": false
#             }
#         }
#     ],
#     "series": [
#         {
#             "name": "\u4eba\u5747",
#             "data": [
#                 2665.0,
#                 1489.0,
#                 1044.0,
#                 994.0,
#                 902.0,
#                 901.0,
#                 846.0,
#                 816.0,
#                 790.0,
#                 768.0
#             ],
#             "markPoint": {
#                 "data": [
#                     {
#                         "symbolSize": 50,
#                         "name": "Minimum",
#                         "type": "min",
#                         "valueDim": null,
#                         "label": {
#                             "normal": {
#                                 "textStyle": {
#                                     "color": "#fff"
#                                 }
#                             }
#                         },
#                         "symbol": "pin"
#                     },
#                     {
#                         "symbolSize": 50,
#                         "name": "Maximum",
#                         "type": "max",
#                         "valueDim": null,
#                         "label": {
#                             "normal": {
#                                 "textStyle": {
#                                     "color": "#fff"
#                                 }
#                             }
#                         },
#                         "symbol": "pin"
#                     }
#                 ]
#             },
#             "barCategoryGap": "20%",
#             "seriesId": 8768910,
#             "stack": "",
#             "type": "bar",
#             "markLine": {
#                 "symbolSize": 10,
#                 "data": [
#                     {
#                         "name": "mean-Value",
#                         "type": "average",
#                         "valueDim": null
#                     }
#                 ]
#             },
#             "label": {
#                 "normal": {
#                     "show": true,
#                     "position": "top",
#                     "formatter": null,
#                     "textStyle": {
#                         "fontSize": 12,
#                         "color": "#000"
#                     }
#                 },
#                 "emphasis": {
#                     "show": true,
#                     "position": null,
#                     "textStyle": {
#                         "fontSize": 12,
#                         "color": "#fff"
#                     }
#                 }
#             }
#         },
#         {
#             "name": "\u8bc4\u8bba\u6570",
#             "data": [
#                 7.0,
#                 0.0,
#                 51.0,
#                 2.0,
#                 19.0,
#                 509.0,
#                 60.0,
#                 5.0,
#                 3.0,
#                 0.0
#             ],
#             "markPoint": {
#                 "data": []
#             },
#             "barCategoryGap": "20%",
#             "seriesId": 8768910,
#             "stack": "",
#             "type": "bar",
#             "markLine": {
#                 "data": []
#             },
#             "label": {
#                 "normal": {
#                     "show": true,
#                     "position": "top",
#                     "formatter": null,
#                     "textStyle": {
#                         "fontSize": 12,
#                         "color": "#000"
#                     }
#                 },
#                 "emphasis": {
#                     "show": true,
#                     "position": null,
#                     "textStyle": {
#                         "fontSize": 12,
#                         "color": "#fff"
#                     }
#                 }
#             }
#         }
#     ],
#     "xAxis": [
#         {
#             "nameLocation": "middle",
#             "min": null,
#             "nameGap": 25,
#             "name": "",
#             "position": null,
#             "axisLabel": {
#                 "margin": 8,
#                 "interval": "auto",
#                 "rotate": 30,
#                 "textStyle": {
#                     "fontSize": 12,
#                     "color": "#000"
#                 }
#             },
#             "boundaryGap": true,
#             "show": true,
#             "nameTextStyle": {
#                 "fontSize": 14
#             },
#             "data": [
#                 "\u9ec4\u516c\u5b50",
#                 "\u5341\u91cc\u6d0b\u573a\u6c5f\u666f\u4f1a\u6240\uff08\u5916\u6ee9\u5e97\uff09",
#                 "MOOK\u9152\u5427",
#                 "\u6d66\u6c5f\u4e8c\u53f7",
#                 "\u83f2\u82983d\u9152\u5427",
#                 "\u6d0b\u623f\u706b\u9505\uff08\u65b0\u5929\u5730\u5e97\uff09",
#                 "\u672c\u8272TureColor\u9152\u5427\uff08\u5916\u6ee9\u5e97\uff09",
#                 "\u5b8f\u8c6a\u6d66\u6c5f\u4e00\u53f7",
#                 "\u539f\u70f9\uff08\u91d1\u8679\u6865\u56fd\u9645\u4e2d\u5fc3\u5e97\uff09",
#                 "\u82b1\u7c60\u5473"
#             ],
#             "inverse": false,
#             "max": null,
#             "type": "category",
#             "axisTick": {
#                 "alignWithLabel": false
#             }
#         }
#     ],
#     "legend": [
#         {
#             "orient": "horizontal",
#             "show": true,
#             "left": "center",
#             "data": [
#                 "\u4eba\u5747",
#                 "\u8bc4\u8bba\u6570"
#             ],
#             "top": "top",
#             "selectedMode": "multiple",
#             "textStyle": {
#                 "fontSize": 12,
#                 "color": "#333"
#             }
#         }
#     ],
#     "series_id": 8768910,
#     "tooltip": {
#         "triggerOn": "mousemove|click",
#         "formatter": null,
#         "textStyle": {
#             "fontSize": 14,
#             "color": "#fff"
#         },
#         "axisPointer": {
#             "type": "line"
#         },
#         "trigger": "item",
#         "backgroundColor": "rgba(50,50,50,0.7)",
#         "borderColor": "#333",
#         "borderWidth": 0
#     },
#     "grid": [
#         {
#             "bottom": "30%"
#         },
#         {
#             "bottom": "30%"
#         }
#     ],
#     "backgroundColor": "#fff",
#     "title": [
#         {
#             "left": "auto",
#             "subtextStyle": {
#                 "fontSize": 12,
#                 "color": "#aaa"
#             },
#             "subtext": "\u6570\u636e\u6765\u6e90\u7f8e*",
#             "textStyle": {
#                 "fontSize": 18,
#                 "color": "#000"
#             },
#             "top": "auto",
#             "text": "\u9910\u996e\u5546\u5bb6\u524d\u5341\u6392\u884c"
#         }
#     ],
#     "toolbox": {
#         "orient": "vertical",
#         "show": true,
#         "left": "95%",
#         "top": "center",
#         "feature": {
#             "restore": {
#                 "show": true
#             },
#             "dataView"

# %% [markdown]
# <div style="float:left;clear:both ;solid 000;margin:2px;">
#     <img src="https://p1.meituan.net/dpgroup/089fb645a439d5112f54709464198ebc2258883.jpg" height="300" width="180"/>
# </div>
# <div style="float:left;border:solid 1px 000;margin:2px;">
#     <img src="https://p0.meituan.net/dpgroup/08c6410707c7ee013fe42f49367a0f873015366.jpg" height="300" width="180"/>
# </div>
# <div style="float:left;border:solid 1px 000;margin:2px;">
#     <img src="https://p1.meituan.net/dpgroup/0d0c119c8c5ed617733543dbc6c814571009636.jpg" height="300" width="180"/>
# </div>
# <div style="float:left;border:solid 1px 000;margin:2px;">
#     <img src="https://p1.meituan.net/dpgroup/b7be7517245ca663efe94ac6d9c52ed22526430.jpg" height="300" width="180"/>
# </div>
# <div style="float:left;border:solid 1px 000;margin:2px;">
#     <img src="https://p1.meituan.net/dpgroup/6285d273f31ab98e1cbe5061747095ad2247619.jpg" height="300" width="180"/>
# </div>

# %% [markdown]
# <div style="float:left;clear:both ;solid 000;margin:2px;">
#     <img src="http://qcloud.dpfile.com/pc/1qJi9p-wLeonVl6Y9WiyFPSanre0MLkueCtCk25iI7w85m6KLxJrZMuRwDiePBFkTYGVDmosZWTLal1WbWRW3A.jpg" height="300" width="180"/>
# </div>
# <div style="float:left;border:solid 1px 000;margin:2px;">
#     <img src="http://qcloud.dpfile.com/pc/o1Jnmy2bPPChRikogYoVC-pw_btvmkBBrWfbZefBAN0kNVqbowOSz6WrD4VBGHSxTYGVDmosZWTLal1WbWRW3A.jpg" height="300" width="180"/>
# </div>
# <div style="float:left;border:solid 1px 000;margin:2px;">
#     <img src="http://qcloud.dpfile.com/pc/exfn_RFUtZ0im46Rl-MXHedTYeJbsQERCP5g57Wid75WzN_4hUPhHPENFzwE2h71TYGVDmosZWTLal1WbWRW3A.jpg" height="300" width="180"/>
# </div>
# <div style="float:left;border:solid 1px 000;margin:2px;">
#     <img src="http://qcloud.dpfile.com/pc/6KngG1CJCk6uC6Ym2VWxmCzc5JFFiQKAAXEcmK-fA_t2Z2NWo8mGzuxwarQuIULZTYGVDmosZWTLal1WbWRW3A.jpg" height="300" width="180"/>
# </div>
# <div style="float:left;border:solid 1px 000;margin:2px;">
#     <img src="http://qcloud.dpfile.com/pc/n_irq9QArm3UMjp0K2j5595shc1P2PGhOOx3gWR1N6gpJ36aly4bqURKSnWlKZwiTYGVDmosZWTLal1WbWRW3A.jpg" height="300" width="180"/>
# </div>

# %% [markdown]
# **菜系分类不同，价格也会不同，所以不能对所有类别进行全量统计（例如日料和小吃的价格就是天壤之别）**

# %%
sql = '''select sub_id,sub_name ,count(*) as cnt from (
	select distinct a.sub_id,a.sub_name,
	b.poi_id,b.title,b.avg_price,b.avg_score,b.comment_num,b.address,b.stamp from meituan_classify_info as a
	inner join meituan_shop_info as b on a.sub_id = b.sub_id and a.class_type = b.class_type
	where a.class_type = 1 and a.sub_id not in(24,393,395)
) as x
group by sub_id,sub_name
'''
df = pd.read_sql(sql,conn,index_col='sub_id')
df
# Out:
#        sub_name  cnt
# sub_id
# 11         蛋糕甜点  247
# 17           火锅  656
# 36         小吃快餐  622
# 40          自助餐  680
# 41         咖啡酒吧  960
# 54         烧烤烤肉  851
# 55          川湘菜  803
# 56          江浙菜  640
# 57           粤菜  600
# 58          西北菜   92
# 59         京菜鲁菜   80
# 60          云贵菜   84
# 62         东南亚菜  201
# 63           海鲜  939
# 227      台湾/客家菜  105
# 228         创意菜  201
# 229      汤/粥/炖菜  217
# 233         新疆菜   82
# 400     中式烧烤/烤串  580
# 20003       东北菜  173
# 20004      香锅烤鱼  702
# 20059      日本料理  651
# 20060      韩国料理  373
