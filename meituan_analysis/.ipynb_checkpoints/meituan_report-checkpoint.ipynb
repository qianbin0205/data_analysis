# %%
import re
import time
from meituan_tools import Operation
import pandas as pd
import pyecharts

# %%
# 数据库连接
op = Operation()
conn = op.db_conn()
cur = conn.cursor()

# %% [markdown]
# + **拿到数据先整体数值字段max,min看下异常数据，这些极值会影响最后统计结果<br />观察后发现人均价格和评分有部分为0，对最后统计没有意义，所以在这里我们需要这些数据进行剔除**

# %%
# 数据检查
sql = '''	select distinct 
	b.poi_id,b.title,b.avg_price,b.avg_score,b.comment_num,b.address from meituan_classify_info as a
	inner join meituan_shop_info as b on a.sub_id = b.sub_id and a.class_type = b.class_type
	where a.class_type = 1 and a.sub_id not in(24,393,395) and b.avg_price <> 0 and b.avg_score <> 0
	order by avg_price desc'''

df = pd.read_sql(sql,conn,index_col=['poi_id'])
df
# Out:
#                           title  avg_price  avg_score  comment_num  \
# poi_id
# 162761320                   黄公子     2665.0        5.0            7
# 2718768           十里洋场江景会所（外滩店）     1489.0        4.0            0
# 1578636                  MOOK酒吧     1044.0        5.0           51
# 1580796                    浦江二号      994.0        5.0            2
# 476286                   菲芘3d酒吧      902.0        4.0           19
# 2473301              洋房火锅（新天地店）      901.0        5.0          509
# 158735513    本色TureColor酒吧（外滩店）      846.0        5.0           60
# 454005                   宏豪浦江一号      816.0        5.0            5
# 40673951           原烹（金虹桥国际中心店）      790.0        5.0            3
# 2730725                     花籠味      768.0        4.5            0
# 6112293                     香然会      723.0        4.5            0
# 159436207        FEELING CLUB酒吧      685.0        5.0           82
# 64049059               榭福屋（静安店）      661.0        4.5            0
# 1607949               晓芹海参（鲁班店）      655.0        3.5            0
# 91906668                    浦江荟      635.0        5.0            6
# 81256882   TheMEAT∙扒餐厅（浦东嘉里大酒店）      616.0        4.0            0
# 83259397              晓芹海参（长宁店）      590.0        3.5            0
# 138245571          蟹的岡田屋（尚嘉中心店）      575.0        4.4            8
# 403296        翡翠36餐厅（浦东香格里拉大酒店）      570.0        3.8           10
# 106050874           SKY酒吧（同乐坊店）      567.0        5.0          385
# 394974          珍御轩（新加坡泰国村鱼翅酒楼）      562.0        4.0            1
# 2661742             外滩悦榕庄-酩缘中餐厅      561.0        3.5            0
# 4973672       MT 1839 Club（闵行店）      551.0        3.9           13
# 2421173             世博源公馆（世博源店）      550.0        4.7          119
# 107503900          蟹的岡田屋（正大广场店）      549.0        4.0           19
# 163519766           伙房水产（陆家嘴总店）      545.0        5.0            1
# 155992192         蟹的岡田屋（绿地缤纷城店）      530.0        4.0           10
# 5153889             外滩悦榕庄-海怡西餐厅      527.0        3.9           17
# 5340006               龙一海鲜（普陀店）      523.0        4.0            7
# 42127593                BM101酒吧      509.0        4.8          539
# ...                         ...        ...        ...          ...
# 89590945        吉合烤饼（嘉杰国际商业广场店）        9.0        4.3          339
# 41396641              鸡翅包饭（松江店）        9.0        4.0         7573
# 2410561            超级奶爸（江桥沃尔玛店）        9.0        4.1         1085
# 96769827       正宗湖南长沙臭豆腐（州桥老街店）        9.0        5.0          338
# 41356582            阿姨奶茶（东门大街店）        9.0        4.4          915
# 78705706        秋满阿姨奶茶（华新宝龙广场店）        9.0        4.6          322
# 99356478          C.忆奶茶（江桥沃尔玛店）        9.0        5.0          560
# 5415000               珍奶工坊（堡镇店）        9.0        4.5          719
# 5949468               快乐柠檬（南门店）        9.0        5.0          312
# 74268107             一品鸡排（华江路店）        9.0        4.6         5360
# 4441687             武汉热干面（民耀路店）        9.0        4.2         2410
# 41461534             和路雪星任冷饮批发部        9.0        5.0          612
# 42067538       阿姨奶茶桥梓湾绿港店（桥梓湾店）        8.0        3.8         3247
# 84978808                 闲趣小吃奶茶        8.0        5.0          135
# 115394563            正新鸡排（青湖路店）        8.0        4.3          577
# 98142819               乐华仕（兴塔店）        8.0        5.0          885
# 82035969                   英伦时光        8.0        5.0          719
# 435280             鲜茶柠檬宝贝（庙前街店）        8.0        3.8         1309
# 94145441            阿姨奶茶（飞航广场店）        8.0        4.5          675
# 73651050                 土耳其肉夹馍        8.0        3.5            0
# 94186511           阿姨奶茶（北翼商业街店）        8.0        5.0          270
# 100932130                  天龙花甲        8.0        5.0          197
# 69767825                 台湾脆皮玉米        7.0        3.4          895
# 88196929            诺亚粥（地纬生活广场）        7.0        5.0           66
# 42283206              晨光烧饼（泗泾店）        6.0        3.5            0
# 111135929       爱乐屋蛋糕房（长兴岛壹街区店）        5.0        5.0          336
# 383698                      金麦坊        5.0        3.8          297
# 83019020                   晨光烧饼        4.0        3.5            0
# 41851753                贡菜香饼家味道        4.0        4.5         1477
# 94594765           张记梅菜扣肉饼（松江店）        3.0        5.0          385
#
#                                                      address
# poi_id
# 162761320                        徐汇区天平路320弄21号1-2层（衡山路花园洋房旁）
# 2718768                                    虹口区黄浦路108号（近外白渡桥）
# 1578636                              静安区南京西路758号汇银大厦5楼（近凤阳路）
# 1580796                               浦东新区滨江大道2250号（近凯宾斯基酒店）
# 476286                                       徐汇区衡山路10号欧登大厦1楼
# 2473301                               黄浦区新天地南里黄陂南路376号（近兴业路）
# 158735513                               黄浦区淮海路东段与柳林路交口柳林大厦六层
# 454005                                   浦东新区滨江大道3788号（近商城路）
# 40673951                                 长宁区茅台路179号金虹桥国际中心4层
# 2730725                                     黄浦区济南路9号2楼（近崇德路）
# 6112293                                浦东新区钦殿街57号（近源深路太清宫道观）
# 159436207                              杨浦区五角场淞沪路151号中环国际大厦3楼
# 64049059                                  静安区胶州路149弄7号（北京西路）
# 1607949                                     卢湾区鲁班路386号（近斜土路）
# 91906668                              浦东新区滨江大道1850号A楼（近浦东南路）
# 81256882                         浦东新区花木路1388号浦东嘉里大酒店2楼（近芳甸路)
# 83259397                                  长宁区长宁路1297号（近凯旋北路）
# 138245571                              长宁区仙霞路99号尚嘉中心3层（近遵义路）
# 403296                       浦东新区富城路33号浦东香格里拉大酒店紫金楼36楼（近名商路)
# 106050874                             静安区余姚路74号靠近海防路路口（同乐坊内）
# 394974                                     杨浦区国定东路237号（近翔殷路）
# 2661742                           虹口区海平路19号上海外滩悦榕庄酒店2楼（公平路口）
# 4973672                            闵行区七莘路1839号财富108广场5楼（顾戴路）
# 2421173                         浦东新区世博大道1368号世博源1区L2层L201-02
# 107503900                   浦东新区陆家嘴西路168号正大广场西区5层26B号（近东方明珠）
# 163519766                         浦东新区东方路778号紫金山大酒店2楼（近世纪大道）
# 155992192  徐汇区瑞平路88号绿地缤纷城1层W-D106、107（地铁龙华中路站5、6、7号出口，靠近东安路）
# 5153889                           虹口区海平路19号鹏欣外滩悦榕庄酒店一楼（公平路口）
# 5340006                                         宝山区古浪路55弄11号
# 42127593                               浦东新区南泉北路528号（新大陆广场3F）
# ...                                                      ...
# 89590945                             虹口区四川北路1727弄嘉杰国际商业广场B1层
# 41396641                                     松江区庙前街54号（侍衣派旁）
# 2410561                             嘉定区曹安公路2118号1030室（沃尔玛一楼）
# 96769827                                  嘉定区博乐路与嘉定东大街交叉口西北角
# 41356582                                浦东新区南汇镇东门大街77号（光明医院）
# 78705706               闵行区华新镇新府中路1536号宝龙城市广场1楼020室（如海、好药师旁边）
# 99356478                       嘉定区江桥镇曹安公路2118号沃尔玛一楼（亚一金店入口处）
# 5415000                                  堡镇堡镇中路153号（渝一锅火锅对面）
# 5949468                                  南门城桥镇新崇南路219号（肯德基旁）
# 74268107                              嘉定区华江路850弄17号（万达金街17号）
# 4441687                               浦东新区民耀路422号1楼（悸动烧仙草旁边）
# 41461534                                      奉贤区南桥镇环城南路935号
# 42067538                         青浦区绿港购物广场105室（SomeCoffee下面）
# 84978808                           青浦区赵重公路2778弄81号（现代华庭小区出口）
# 115394563                                         青浦区青湖路899号
# 98142819                                      金山区兴塔镇新金山路289号
# 82035969                                       青浦区崧文南路169弄3号
# 435280                                             松江区庙前街54号
# 94145441                              松江区玉树路2581-2583号飞航广场1层
# 73651050                                          黄浦区天津路159号
# 94186511                                宝山区牡丹江路1599号北翼商业街F1号
# 100932130                                    青浦区庆华一路北门街3号15弄
# 69767825                                 松江区庙前街98号（周黑鸭同一个门面）
# 88196929                         浦东新区川沙新镇新德西路100弄101号（地纬广场内）
# 42283206                                         松江区横港公路638号
# 111135929              长兴岛长兴镇凤凰镇丰福路599弄金滂路178号109室近月牙港路久久鸭旁边
# 383698                              长宁区玉屏南路340弄（玉屏南路与遵义路交汇处）
# 83019020                                          嘉定区南大街131号
# 41851753                                          松江区庙前街105号
# 94594765                                   松江区庙前街二十三号（沃尔玛旁边）
#
# [8003 rows x 5 columns]

# %%
from pyecharts import Liquid

liquid = Liquid(title="样本数",subtitle='样本总量29876 剔除均价和评分为0的数据所剩的数量26793')
liquid.add("Liquid", [0.89, 0.7, 0.5, 0.3], is_liquid_outline_show=False)
liquid
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min', 'liquidfill': '/nbextensions/echarts/echarts-liquidfill.min'
#         }
#     });
# </script>
#     <div id="1c6907cce3914e288c095374663194cd" style="width:800px;height:400px;"></div>
#
#
# <script>
#     require(['echarts', 'liquidfill'], function(echarts) {
#
# var myChart_1c6907cce3914e288c095374663194cd = echarts.init(document.getElementById('1c6907cce3914e288c095374663194cd'), null, {renderer: 'canvas'});
# var option_1c6907cce3914e288c095374663194cd = {
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597",
#         "#f6f5ec"
#     ],
#     "legend": [
#         {
#             "orient": "horizontal",
#             "selectedMode": "multiple",
#             "top": "top",
#             "data": [],
#             "show": true,
#             "textStyle": {
#                 "color": "#333",
#                 "fontSize": 12
#             },
#             "left": "center"
#         }
#     ],
#     "backgroundColor": "#fff",
#     "toolbox": {
#         "show": true,
#         "orient": "vertical",
#         "feature": {
#             "saveAsImage": {
#                 "show": true,
#                 "title": "\u4e0b\u8f7d\u56fe\u7247"
#             },
#             "dataView": {
#                 "show": true
#             },
#             "restore": {
#                 "show": true
#             }
#         },
#         "top": "center",
#         "left": "95%"
#     },
#     "series_id": 28835,
#     "tooltip": {
#         "textStyle": {
#             "color": "#fff",
#             "fontSize": 14
#         },
#         "trigger": "item",
#         "borderWidth": 0,
#         "backgroundColor": "rgba(50,50,50,0.7)",
#         "axisPointer": {
#             "type": "line"
#         },
#         "triggerOn": "mousemove|click",
#         "formatter": null,
#         "borderColor": "#333"
#     },
#     "title": [
#         {
#             "subtextStyle": {
#                 "color": "#aaa",
#                 "fontSize": 12
#             },
#             "subtext": "\u6837\u672c\u603b\u91cf29876 \u5254\u9664\u5747\u4ef7\u548c\u8bc4\u5206\u4e3a0\u7684\u6570\u636e\u6240\u5269\u7684\u6570\u91cf26793",
#             "top": "auto",
#             "text": "\u6837\u672c\u6570",
#             "textStyle": {
#                 "color": "#000",
#                 "fontSize": 18
#             },
#             "left": "auto"
#         }
#     ],
#     "series": [
#         {
#             "type": "liquidFill",
#             "color": [
#                 "#294D99",
#                 "#156ACF",
#                 "#1598ED",
#                 "#45BDFF"
#             ],
#             "animationDuration": 2000,
#             "waveAnimation": true,
#             "data": [
#                 0.89,
#                 0.7,
#                 0.5,
#                 0.3
#             ],
#             "shape": "circle",
#             "outline": {
#                 "show": false
#             },
#             "animationDurationUpdate": 1000,
#             "name": "Liquid"
#         }
#     ]
# };
# myChart_1c6907cce3914e288c095374663194cd.setOption(option_1c6907cce3914e288c095374663194cd);
#
#     });
# </script>

# %%
df = df.head(10)
title = df['title']
avg_price =  df['avg_price']
avg_score = df['avg_score']
comment_num = df['comment_num']

from pyecharts import Bar,Grid

bar = Bar(title="餐饮商家前十排行",subtitle='数据来源神秘组织：*团',width=800,height=400)
bar.add("人均", title, avg_price, mark_point=["min", "max"],mark_line=["average"])
bar.add("评论数", title, comment_num,mark_point=["max"],is_label_show=True, xaxis_rotate=30)

grid = Grid(height=500)
grid.add(bar, grid_bottom="30%")

grid
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min'
#         }
#     });
# </script>
#     <div id="8483625779ce475c9e2f354171c8cdd2" style="width:800px;height:500px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#
# var myChart_8483625779ce475c9e2f354171c8cdd2 = echarts.init(document.getElementById('8483625779ce475c9e2f354171c8cdd2'), null, {renderer: 'canvas'});
# var option_8483625779ce475c9e2f354171c8cdd2 = {
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597",
#         "#f6f5ec"
#     ],
#     "legend": [
#         {
#             "orient": "horizontal",
#             "selectedMode": "multiple",
#             "top": "top",
#             "data": [
#                 "\u4eba\u5747",
#                 "\u8bc4\u8bba\u6570"
#             ],
#             "show": true,
#             "textStyle": {
#                 "color": "#333",
#                 "fontSize": 12
#             },
#             "left": "center"
#         }
#     ],
#     "yAxis": [
#         {
#             "type": "value",
#             "nameGap": 25,
#             "axisTick": {
#                 "alignWithLabel": false
#             },
#             "inverse": false,
#             "min": null,
#             "nameLocation": "middle",
#             "position": null,
#             "axisLabel": {
#                 "formatter": "{value} ",
#                 "interval": "auto",
#                 "rotate": 0,
#                 "margin": 8,
#                 "textStyle": {
#                     "color": "#000",
#                     "fontSize": 12
#                 }
#             },
#             "name": "",
#             "boundaryGap": true,
#             "max": null,
#             "splitLine": {
#                 "show": true
#             },
#             "show": true,
#             "nameTextStyle": {
#                 "fontSize": 14
#             }
#         }
#     ],
#     "series": [
#         {
#             "type": "bar",
#             "label": {
#                 "normal": {
#                     "show": false,
#                     "textStyle": {
#                         "color": "#000",
#                         "fontSize": 12
#                     },
#                     "formatter": null,
#                     "position": "top"
#                 },
#                 "emphasis": {
#                     "show": true,
#                     "textStyle": {
#                         "color": "#fff",
#                         "fontSize": 12
#                     },
#                     "position": null
#                 }
#             },
#             "markLine": {
#                 "symbolSize": 10,
#                 "data": [
#                     {
#                         "type": "average",
#                         "valueDim": null,
#                         "name": "mean-Value"
#                     }
#                 ]
#             },
#             "data": [
#                 2665.0,
#                 1489.0,
#                 1044.0,
#                 994.0,
#                 902.0,
#                 901.0,
#                 846.0,
#                 816.0,
#                 790.0,
#                 768.0
#             ],
#             "seriesId": 611789,
#             "name": "\u4eba\u5747",
#             "markPoint": {
#                 "data": [
#                     {
#                         "type": "min",
#                         "valueDim": null,
#                         "symbolSize": 50,
#                         "label": {
#                             "normal": {
#                                 "textStyle": {
#                                     "color": "#fff"
#                                 }
#                             }
#                         },
#                         "symbol": "pin",
#                         "name": "Minimum"
#                     },
#                     {
#                         "type": "max",
#                         "valueDim": null,
#                         "symbolSize": 50,
#                         "label": {
#                             "normal": {
#                                 "textStyle": {
#                                     "color": "#fff"
#                                 }
#                             }
#                         },
#                         "symbol": "pin",
#                         "name": "Maximum"
#                     }
#                 ]
#             },
#             "barCategoryGap": "20%",
#             "stack": ""
#         },
#         {
#             "type": "bar",
#             "label": {
#                 "normal": {
#                     "show": true,
#                     "textStyle": {
#                         "color": "#000",
#                         "fontSize": 12
#                     },
#                     "formatter": null,
#                     "position": "top"
#                 },
#                 "emphasis": {
#                     "show": true,
#                     "textStyle": {
#                         "color": "#fff",
#                         "fontSize": 12
#                     },
#                     "position": null
#                 }
#             },
#             "markLine": {
#                 "data": []
#             },
#             "data": [
#                 7.0,
#                 0.0,
#                 51.0,
#                 2.0,
#                 19.0,
#                 509.0,
#                 60.0,
#                 5.0,
#                 3.0,
#                 0.0
#             ],
#             "seriesId": 611789,
#             "name": "\u8bc4\u8bba\u6570",
#             "markPoint": {
#                 "data": [
#                     {
#                         "type": "max",
#                         "valueDim": null,
#                         "symbolSize": 50,
#                         "label": {
#                             "normal": {
#                                 "textStyle": {
#                                     "color": "#fff"
#                                 }
#                             }
#                         },
#                         "symbol": "pin",
#                         "name": "Maximum"
#                     }
#                 ]
#             },
#             "barCategoryGap": "20%",
#             "stack": ""
#         }
#     ],
#     "backgroundColor": "#fff",
#     "grid": [
#         {
#             "bottom": "30%"
#         },
#         {
#             "bottom": "30%"
#         }
#     ],
#     "xAxis": [
#         {
#             "type": "category",
#             "nameGap": 25,
#             "axisTick": {
#                 "alignWithLabel": false
#             },
#             "inverse": false,
#             "min": null,
#             "nameLocation": "middle",
#             "position": null,
#             "axisLabel": {
#                 "rotate": 30,
#                 "interval": "auto",
#                 "margin": 8,
#                 "textStyle": {
#                     "color": "#000",
#                     "fontSize": 12
#                 }
#             },
#             "name": "",
#             "boundaryGap": true,
#             "max": null,
#             "data": [
#                 "\u9ec4\u516c\u5b50",
#                 "\u5341\u91cc\u6d0b\u573a\u6c5f\u666f\u4f1a\u6240\uff08\u5916\u6ee9\u5e97\uff09",
#                 "MOOK\u9152\u5427",
#                 "\u6d66\u6c5f\u4e8c\u53f7",
#                 "\u83f2\u82983d\u9152\u5427",
#                 "\u6d0b\u623f\u706b\u9505\uff08\u65b0\u5929\u5730\u5e97\uff09",
#                 "\u672c\u8272TureColor\u9152\u5427\uff08\u5916\u6ee9\u5e97\uff09",
#                 "\u5b8f\u8c6a\u6d66\u6c5f\u4e00\u53f7",
#                 "\u539f\u70f9\uff08\u91d1\u8679\u6865\u56fd\u9645\u4e2d\u5fc3\u5e97\uff09",
#                 "\u82b1\u7c60\u5473"
#             ],
#             "show": true,
#             "nameTextStyle": {
#                 "fontSize": 14
#             }
#         }
#     ],
#     "series_id": 611789,
#     "tooltip": {

# %% [markdown]
# + **对人均降序排序后，发现最贵的是“黄公子”人均2665，不由得让我们对前10的商家起了兴趣，于是上了百度查看了一下**

# %% [markdown]
# >+ **[【黄公子】](http://s.dianping.com/topic/33883578?utm_source=forum_pc_index)<br />
# 隐藏在老式洋房里的一家人均千元的定制私房菜，仪式感十足，每天只接受10位顾客的预定，简友们谁家宽裕的可以带我去遛遛 =。=**

# %% [markdown]
# <div style="float:left;clear:both ;solid 000;margin:2px;">
#     <img src="https://p1.meituan.net/dpgroup/089fb645a439d5112f54709464198ebc2258883.jpg" height="300" width="180"/>
# </div>
# <div style="float:left;border:solid 1px 000;margin:2px;">
#     <img src="https://p0.meituan.net/dpgroup/08c6410707c7ee013fe42f49367a0f873015366.jpg" height="300" width="180"/>
# </div>
# <div style="float:left;border:solid 1px 000;margin:2px;">
#     <img src="https://p1.meituan.net/dpgroup/0d0c119c8c5ed617733543dbc6c814571009636.jpg" height="300" width="180"/>
# </div>
# <div style="float:left;border:solid 1px 000;margin:2px;">
#     <img src="https://p1.meituan.net/dpgroup/b7be7517245ca663efe94ac6d9c52ed22526430.jpg" height="300" width="180"/>
# </div>
# <div style="float:left;border:solid 1px 000;margin:2px;">
#     <img src="https://p1.meituan.net/dpgroup/6285d273f31ab98e1cbe5061747095ad2247619.jpg" height="300" width="180"/>
# </div>

# %% [markdown]
# >+ **[【MOOK酒吧】](http://www.dianping.com/shop/5583053)<br />什么是“当当当当，当当当?” 天哪! 还有漂亮的小姐姐...~哇靠~仿佛恋爱了... =。=**

# %% [markdown]
# <div style="float:left;clear:both ;solid 000;margin:2px;">
#     <img src="http://qcloud.dpfile.com/pc/fh2O7aK9LdOvLZsPRasECbn4uJsOpNAw0yd7AzdTGAf9FiMxfamhzOpBpUB36ZKETYGVDmosZWTLal1WbWRW3A.jpg" height="300" width="180"/>
# </div>
# <div style="float:left;border:solid 1px 000;margin:2px;">
#     <img src="http://qcloud.dpfile.com/pc/CvQummZpOhNfK0n2sPv8sFcmkPzo3yecpXgwr1Lrzd4kNVqbowOSz6WrD4VBGHSxTYGVDmosZWTLal1WbWRW3A.jpg" height="300" width="180"/>
# </div>
# <div style="float:left;border:solid 1px 000;margin:2px;">
#     <img src="http://qcloud.dpfile.com/pc/Kjehf2z1DpAYJShzXNEcud6V7W2TsUTmYRErB8FI7s44OnA797ve0qcViZcSKwMVTYGVDmosZWTLal1WbWRW3A.jpg" height="300" width="180"/>
# </div>
# <div style="float:left;border:solid 1px 000;margin:2px;">
#     <img src="http://qcloud.dpfile.com/pc/PMC7S3ty3JH3sw-xVP93x3TSsjarY5GxYx-gycoJzhsru7nMSCtlSj7iGU77jW6uTYGVDmosZWTLal1WbWRW3A.jpg" height="300" width="180"/>
# </div>
# <div style="float:left;border:solid 1px 000;margin:2px;">
#     <img src="http://qcloud.dpfile.com/pc/DdbjvXy730rUs9XFo8gqiZ29HqXj0m1tsQE87NFZxXMTsu-eL1pFIl8y1JR6Gd7YTYGVDmosZWTLal1WbWRW3A.jpg" height="300" width="180"/>
# </div>

# %% [markdown]
# >+ **[【洋房火锅】](http://www.dianping.com/shop/8844957)<br />火锅中的劳斯莱斯...A级和牛600~800,涮一片牛肉小两百...我的天...贫穷真的限制我了我的想象 =。=**

# %% [markdown]
# <div style="float:left;clear:both ;solid 000;margin:2px;">
#     <img src="http://qcloud.dpfile.com/pc/1qJi9p-wLeonVl6Y9WiyFPSanre0MLkueCtCk25iI7w85m6KLxJrZMuRwDiePBFkTYGVDmosZWTLal1WbWRW3A.jpg" height="300" width="180"/>
# </div>
# <div style="float:left;border:solid 1px 000;margin:2px;">
#     <img src="http://qcloud.dpfile.com/pc/o1Jnmy2bPPChRikogYoVC-pw_btvmkBBrWfbZefBAN0kNVqbowOSz6WrD4VBGHSxTYGVDmosZWTLal1WbWRW3A.jpg" height="300" width="180"/>
# </div>
# <div style="float:left;border:solid 1px 000;margin:2px;">
#     <img src="http://qcloud.dpfile.com/pc/exfn_RFUtZ0im46Rl-MXHedTYeJbsQERCP5g57Wid75WzN_4hUPhHPENFzwE2h71TYGVDmosZWTLal1WbWRW3A.jpg" height="300" width="180"/>
# </div>
# <div style="float:left;border:solid 1px 000;margin:2px;">
#     <img src="http://qcloud.dpfile.com/pc/6KngG1CJCk6uC6Ym2VWxmCzc5JFFiQKAAXEcmK-fA_t2Z2NWo8mGzuxwarQuIULZTYGVDmosZWTLal1WbWRW3A.jpg" height="300" width="180"/>
# </div>
# <div style="float:left;border:solid 1px 000;margin:2px;">
#     <img src="http://qcloud.dpfile.com/pc/n_irq9QArm3UMjp0K2j5595shc1P2PGhOOx3gWR1N6gpJ36aly4bqURKSnWlKZwiTYGVDmosZWTLal1WbWRW3A.jpg" height="300" width="180"/>
# </div>

# %% [markdown]
# + **看完最贵的，那么我们看下最热的，也就是评论数最多的**

# %%
sql3 = '''#sql3
select distinct a.sub_id,a.sub_name,
b.poi_id,b.title,b.avg_price,b.avg_score,b.comment_num,b.address from meituan_classify_info as a
inner join meituan_shop_info as b on a.sub_id = b.sub_id and a.class_type = b.class_type
where a.class_type = 1 and a.sub_id not in(24,393,395) and b.avg_price <> 0 and b.avg_score <> 0 
and CONCAT(b.sub_id,b.poi_id) not in ('6342030772','4050576755','6350576755','4052163162','2006068147006','5452800270','4087812358','6387812358','543311762')
order by b.comment_num desc limit 10;
'''
df3 = pd.read_sql(sql3,conn)
df3
# Out:
#    sub_id sub_name    poi_id                   title  avg_price  avg_score  \
# 0      36     小吃快餐   4091974            方燕烤猪蹄店（罗宾森店）       10.0        4.5
# 1      40      自助餐   5396841        多伦多海鲜自助餐厅（江桥万达店）       99.0        3.9
# 2      40      自助餐  42030772  上海贻贝湾海鲜自助餐厅(百联南桥购物中心店)       95.0        3.6
# 3      36     小吃快餐   5565604           西安章记（曹路宝龙广场店）       18.0        4.8
# 4      36     小吃快餐   4137469             盘古烤猪蹄（鹿都总店）       13.0        4.8
# 5      17       火锅  68147006        牛市缘潮汕鲜牛肉火锅（乐颂坊店）       92.0        3.6
# 6      40      自助餐  52800270          炭香园自助烧烤（人民北路店）       57.0        3.7
# 7      36     小吃快餐   1584738          粉面桃花土豆粉（天钥桥路店）       24.0        4.3
# 8      40      自助餐   3311762           圣火营BBQ（南京东路店）       57.0        3.6
# 9      40      自助餐  40833128  鑫海汇海鲜烤肉火锅自助餐厅（巴黎春天天山店）       70.0        3.3
#
#    comment_num                               address
# 0        24454                嘉定区城中路138号罗宾森广场南侧2号美食亭
# 1        20887  嘉定区华江路848号江桥万达广场百货楼5楼5001铺位（金运路地铁站东）
# 2        19742                奉贤区百齐路588号百联南桥购物中心二期5层
# 3        17250                浦东新区金海路2505号曹路宝龙广场一期1层
# 4        15749                     松江区庙前街98号（面潮未来旁边）
# 5        14510                      松江区松汇中路568号乐颂坊3楼
# 6        13114                 松江区人民北路112号三楼（招商银行楼上）
# 7        12772                    徐汇区天钥桥路93-3号（近美罗城）
# 8        12272             黄浦区南京东路588号丝绸商厦6楼（世纪广场对面）
# 9        12105                    长宁区天山路762号巴黎春天中区4层

# %% [markdown]
# + **从数据表中可以看出，整个评论排行榜的前十均被 小吃快餐、自助餐 2类霸榜（其中还剔除了各种xxx分店），有趣的是前十店铺的地址大多都在 嘉定、奉贤、松江、曹路 这些地区都在上海外环以外，离市区是相当远，兄die!我想去吃吃验证下都心有余而力不足。最后这两类分类到底是否真的是客量大，还是存在刷榜，或是神秘组织\*团商铺分类关系，个人就不深度去研究了...太花费时间，但我真的很好奇~知道的简友们请留言...**

# %%
from pyecharts import Bar,Grid

data = sorted(df3[['title','comment_num']].values ,key=lambda x: x[1],reverse=True)
attr = [i[0] for i in data]
val = [i[1] for i in data]

bar = Bar()
bar.add('comment_num', attr, val,is_label_show=True,xaxis_rotate=30)
grid3 = Grid(height=500)
grid3.add(bar, grid_bottom="30%")

grid3
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min'
#         }
#     });
# </script>
#     <div id="e0046a146a264bc9953f29eec4228bc4" style="width:800px;height:500px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#
# var myChart_e0046a146a264bc9953f29eec4228bc4 = echarts.init(document.getElementById('e0046a146a264bc9953f29eec4228bc4'), null, {renderer: 'canvas'});
# var option_e0046a146a264bc9953f29eec4228bc4 = {
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597",
#         "#f6f5ec"
#     ],
#     "legend": [
#         {
#             "orient": "horizontal",
#             "selectedMode": "multiple",
#             "top": "top",
#             "data": [
#                 "comment_num"
#             ],
#             "show": true,
#             "textStyle": {
#                 "color": "#333",
#                 "fontSize": 12
#             },
#             "left": "center"
#         }
#     ],
#     "yAxis": [
#         {
#             "type": "value",
#             "nameGap": 25,
#             "axisTick": {
#                 "alignWithLabel": false
#             },
#             "inverse": false,
#             "min": null,
#             "nameLocation": "middle",
#             "position": null,
#             "axisLabel": {
#                 "formatter": "{value} ",
#                 "interval": "auto",
#                 "rotate": 0,
#                 "margin": 8,
#                 "textStyle": {
#                     "color": "#000",
#                     "fontSize": 12
#                 }
#             },
#             "name": "",
#             "boundaryGap": true,
#             "max": null,
#             "splitLine": {
#                 "show": true
#             },
#             "show": true,
#             "nameTextStyle": {
#                 "fontSize": 14
#             }
#         }
#     ],
#     "series": [
#         {
#             "type": "bar",
#             "label": {
#                 "normal": {
#                     "show": true,
#                     "textStyle": {
#                         "color": "#000",
#                         "fontSize": 12
#                     },
#                     "formatter": null,
#                     "position": "top"
#                 },
#                 "emphasis": {
#                     "show": true,
#                     "textStyle": {
#                         "color": "#fff",
#                         "fontSize": 12
#                     },
#                     "position": null
#                 }
#             },
#             "markLine": {
#                 "data": []
#             },
#             "data": [
#                 24454,
#                 20887,
#                 19742,
#                 17250,
#                 15749,
#                 14510,
#                 13114,
#                 12772,
#                 12272,
#                 12105
#             ],
#             "seriesId": 3822575,
#             "name": "comment_num",
#             "markPoint": {
#                 "data": []
#             },
#             "barCategoryGap": "20%",
#             "stack": ""
#         }
#     ],
#     "backgroundColor": "#fff",
#     "grid": [
#         {
#             "bottom": "30%"
#         }
#     ],
#     "toolbox": {
#         "show": true,
#         "orient": "vertical",
#         "top": "center",
#         "feature": {
#             "saveAsImage": {
#                 "show": true,
#                 "title": "\u4e0b\u8f7d\u56fe\u7247"
#             },
#             "dataView": {
#                 "show": true
#             },
#             "restore": {
#                 "show": true
#             }
#         },
#         "left": "95%"
#     },
#     "series_id": 3822575,
#     "tooltip": {
#         "formatter": null,
#         "trigger": "item",
#         "borderWidth": 0,
#         "backgroundColor": "rgba(50,50,50,0.7)",
#         "textStyle": {
#             "color": "#fff",
#             "fontSize": 14
#         },
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "borderColor": "#333"
#     },
#     "title": [
#         {
#             "subtext": "",
#             "top": "auto",
#             "text": "",
#             "left": "auto",
#             "textStyle": {
#                 "color": "#000",
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "color": "#aaa",
#                 "fontSize": 12
#             }
#         }
#     ],
#     "xAxis": [
#         {
#             "type": "category",
#             "nameGap": 25,
#             "axisTick": {
#                 "alignWithLabel": false
#             },
#             "inverse": false,
#             "min": null,
#             "nameLocation": "middle",
#             "position": null,
#             "axisLabel": {
#                 "rotate": 30,
#                 "interval": "auto",
#                 "margin": 8,
#                 "textStyle": {
#                     "color": "#000",
#                     "fontSize": 12
#                 }
#             },
#             "name": "",
#             "boundaryGap": true,
#             "max": null,
#             "data": [
#                 "\u65b9\u71d5\u70e4\u732a\u8e44\u5e97\uff08\u7f57\u5bbe\u68ee\u5e97\uff09",
#                 "\u591a\u4f26\u591a\u6d77\u9c9c\u81ea\u52a9\u9910\u5385\uff08\u6c5f\u6865\u4e07\u8fbe\u5e97\uff09",
#                 "\u4e0a\u6d77\u8d3b\u8d1d\u6e7e\u6d77\u9c9c\u81ea\u52a9\u9910\u5385(\u767e\u8054\u5357\u6865\u8d2d\u7269\u4e2d\u5fc3\u5e97)",
#                 "\u897f\u5b89\u7ae0\u8bb0\uff08\u66f9\u8def\u5b9d\u9f99\u5e7f\u573a\u5e97\uff09",
#                 "\u76d8\u53e4\u70e4\u732a\u8e44\uff08\u9e7f\u90fd\u603b\u5e97\uff09",
#                 "\u725b\u5e02\u7f18\u6f6e\u6c55\u9c9c\u725b\u8089\u706b\u9505\uff08\u4e50\u9882\u574a\u5e97\uff09",
#                 "\u70ad\u9999\u56ed\u81ea\u52a9\u70e7\u70e4\uff08\u4eba\u6c11\u5317\u8def\u5e97\uff09",
#                 "\u7c89\u9762\u6843\u82b1\u571f\u8c46\u7c89\uff08\u5929\u94a5\u6865\u8def\u5e97\uff09",
#                 "\u5723\u706b\u8425BBQ\uff08\u5357\u4eac\u4e1c\u8def\u5e97\uff09",
#                 "\u946b\u6d77\u6c47\u6d77\u9c9c\u70e4\u8089\u706b\u9505\u81ea\u52a9\u9910\u5385\uff08\u5df4\u9ece\u6625\u5929\u5929\u5c71\u5e97\uff09"
#             ],
#             "show": true,
#             "nameTextStyle": {
#                 "fontSize": 14
#             }
#         }
#     ]
# };
# myChart_e0046a146a264bc9953f29eec4228bc4.setOption(option_e0046a146a264bc9953f29eec4228bc4);
#
#     });
# </script>

# %% [markdown]
# > [【燕烤猪蹄店】](http://www.dianping.com/shop/58919293)
# >+ **评论数量第一的竟然是家烤猪蹄店，个人是超级喜欢吃猪蹄的，皮脆肉软还美颜...Duang!!但为何以如此高的评论数位居榜首？对这块了解的请留言告知~(喜欢图3的请为我点赞!)**

# %% [markdown]
# <div style="float:left;border:solid 1px 000;margin:2px;">
#     <img src="http://qcloud.dpfile.com/pc/ktUEW5kKJiEidB7kDqF_j1a0z62NhOm5YlkD4uLuOaxF3HNB3vggzmw8raY1JNntTYGVDmosZWTLal1WbWRW3A.jpg" height="300" width="330"/>
# </div>
# <div style="float:left;border:solid 1px 000;margin:2px;">
#     <img src="http://qcloud.dpfile.com/pc/Evr544EhAIuulJNnEolo1ADBfIGYusZQGC9aZIW_qG4LPJtbh_j3JRHoujrHxBzGTYGVDmosZWTLal1WbWRW3A.jpg" height="300" width="330"/>
# </div>
# </div>
# <div style="float:left;border:solid 1px 000;margin:2px;">
#     <img src="http://qcloud.dpfile.com/pc/Qc0poBNvPAog_0wiqSoRscCswJHzgdj1ZJ52VUVRRPJJZLFfMo2DngJBqjtlKhWfTYGVDmosZWTLal1WbWRW3A.jpg" height="300" width="300"/>
# </div>

# %% [markdown]
# + **对餐厅感兴趣的可以点餐厅链接↑↑↑ <br /> <br />好了，言归正传，分类不同，价格会相差很大，所以不能对所有类别进行全量统计（例如日料和小吃的价格就是天壤之别）下面的箱线图就很好的表达了这些分类的数据分布情况（ps：箱线图可以表达很多基础分布,最上线表示最大，最下线表示最小，箱体内表示整体中正常数据，箱体外表示整体中部分突变数据，箱体中线表示中分为，箱体上框表示3分位，箱体下框表示7分位）**

# %%
from pyecharts import Boxplot

sql = '''select distinct sub_id,sub_name from meituan_classify_info where class_type = 1 and sub_id not in(24,393,395)'''
df = pd.read_sql(sql,conn)

sql2 = '''select distinct poi_id,avg_price,sub_id from meituan_shop_info where class_type = 1 and avg_price <> 0 and avg_score <> 0'''
df2 = pd.read_sql(sql2,conn)

# %%
x_axis = []
y_axis = []
for i in df.index:
    sub_id = df.loc[i].values[0]
    sub_name = df.loc[i].values[1]  
    avg_price = df2[df2['sub_id'] == sub_id ]['avg_price'].values
    x_axis.append(sub_name)
    y_axis.append(avg_price)
    
boxplot = Boxplot("菜系数据分布情况")
_yaxis = boxplot.prepare_data(y_axis)   # 转换数据
tp_dict = {k:v for k,v in zip(x_axis,_yaxis)}
idx_tp = sorted([(max(v),k) for k,v in zip(x_axis,_yaxis)])

# 根据max排序
x_ax = []
y_ax = []
for i in idx_tp:
    x_ax.append(i[1])
    y_ax.append(tp_dict[i[1]])
boxplot.add('boxplot', x_ax,y_ax,is_datazoom_show=True, datazoom_type='both',xaxis_rotate=30)

grid = Grid()
grid.add(boxplot, grid_bottom="20%")
grid
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min'
#         }
#     });
# </script>
#     <div id="8284abd964cf40418ed19cc9595c1111" style="width:800px;height:400px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#
# var myChart_8284abd964cf40418ed19cc9595c1111 = echarts.init(document.getElementById('8284abd964cf40418ed19cc9595c1111'), null, {renderer: 'canvas'});
# var option_8284abd964cf40418ed19cc9595c1111 = {
#     "yAxis": [
#         {
#             "nameLocation": "middle",
#             "min": null,
#             "splitLine": {
#                 "show": true
#             },
#             "show": true,
#             "position": null,
#             "axisLabel": {
#                 "margin": 8,
#                 "interval": "auto",
#                 "formatter": "{value} ",
#                 "rotate": 0,
#                 "textStyle": {
#                     "fontSize": 12,
#                     "color": "#000"
#                 }
#             },
#             "boundaryGap": true,
#             "name": "",
#             "nameTextStyle": {
#                 "fontSize": 14
#             },
#             "nameGap": 25,
#             "inverse": false,
#             "max": null,
#             "type": "value",
#             "axisTick": {
#                 "alignWithLabel": false
#             }
#         }
#     ],
#     "tooltip": {
#         "triggerOn": "mousemove|click",
#         "formatter": null,
#         "textStyle": {
#             "fontSize": 14,
#             "color": "#fff"
#         },
#         "axisPointer": {
#             "type": "line"
#         },
#         "trigger": "item",
#         "backgroundColor": "rgba(50,50,50,0.7)",
#         "borderColor": "#333",
#         "borderWidth": 0
#     },
#     "dataZoom": [
#         {
#             "orient": "horizontal",
#             "show": true,
#             "xAxisIndex": null,
#             "end": 100,
#             "type": "slider",
#             "yAxisIndex": null,
#             "start": 50
#         },
#         {
#             "orient": "horizontal",
#             "show": true,
#             "start": 50,
#             "end": 100,
#             "type": "inside",
#             "yAxisIndex": null,
#             "xAxisIndex": null
#         }
#     ],
#     "toolbox": {
#         "orient": "vertical",
#         "show": true,
#         "left": "95%",
#         "top": "center",
#         "feature": {
#             "restore": {
#                 "show": true
#             },
#             "dataView": {
#                 "show": true
#             },
#             "saveAsImage": {
#                 "show": true,
#                 "title": "\u4e0b\u8f7d\u56fe\u7247"
#             }
#         }
#     },
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597",
#         "#f6f5ec"
#     ],
#     "series": [
#         {
#             "name": "boxplot",
#             "data": [
#                 [
#                     16.0,
#                     50.0,
#                     73.0,
#                     82.0,
#                     111.0
#                 ],
#                 [
#                     11.0,
#                     31.5,
#                     49.0,
#                     70.0,
#                     127.0
#                 ],
#                 [
#                     8.0,
#                     21.0,
#                     37.5,
#                     67.0,
#                     127.0
#                 ],
#                 [
#                     7.0,
#                     16.5,
#                     23.0,
#                     49.0,
#                     128.0
#                 ],
#                 [
#                     4.0,
#                     42.0,
#                     52.0,
#                     61.5,
#                     149.0
#                 ],
#                 [
#                     15.0,
#                     38.0,
#                     50.0,
#                     61.0,
#                     188.0
#                 ],
#                 [
#                     8.0,
#                     46.5,
#                     63.0,
#                     82.0,
#                     206.0
#                 ],
#                 [
#                     17.0,
#                     42.0,
#                     58.0,
#                     90.5,
#                     226.0
#                 ],
#                 [
#                     3.0,
#                     16.0,
#                     21.0,
#                     33.0,
#                     267.0
#                 ],
#                 [
#                     19.0,
#                     65.0,
#                     88.0,
#                     106.0,
#                     294.0
#                 ],
#                 [
#                     16.0,
#                     43.0,
#                     54.0,
#                     68.0,
#                     312.0
#                 ],
#                 [
#                     15.0,
#                     41.75,
#                     75.0,
#                     126.5,
#                     329.0
#                 ],
#                 [
#                     5.0,
#                     14.0,
#                     19.0,
#                     33.0,
#                     339.0
#                 ],
#                 [
#                     14.0,
#                     50.0,
#                     73.0,
#                     90.0,
#                     398.0
#                 ],
#                 [
#                     8.0,
#                     50.0,
#                     67.0,
#                     87.0,
#                     468.0
#                 ],
#                 [
#                     12.0,
#                     58.0,
#                     77.5,
#                     104.25,
#                     506.0
#                 ],
#                 [
#                     17.0,
#                     65.0,
#                     116.0,
#                     200.5,
#                     616.0
#                 ],
#                 [
#                     14.0,
#                     77.5,
#                     119.0,
#                     187.0,
#                     790.0
#                 ],
#                 [
#                     15.0,
#                     63.0,
#                     89.0,
#                     123.75,
#                     790.0
#                 ],
#                 [
#                     14.0,
#                     56.0,
#                     73.0,
#                     92.0,
#                     901.0
#                 ],
#                 [
#                     10.0,
#                     36.0,
#                     50.0,
#                     82.5,
#                     1044.0
#                 ],
#                 [
#                     11.0,
#                     57.0,
#                     83.5,
#                     133.0,
#                     1489.0
#                 ],
#                 [
#                     15.0,
#                     50.0,
#                     73.5,
#                     122.5,
#                     2665.0
#                 ]
#             ],
#             "markPoint": {
#                 "data": []
#             },
#             "seriesId": 3726830,
#             "type": "boxplot",
#             "markLine": {
#                 "data": []
#             },
#             "label": {
#                 "normal": {
#                     "show": false,
#                     "position": "top",
#                     "formatter": null,
#                     "textStyle": {
#                         "fontSize": 12,
#                         "color": "#000"
#                     }
#                 },
#                 "emphasis": {
#                     "show": true,
#                     "position": null,
#                     "textStyle": {
#                         "fontSize": 12,
#                         "color": "#fff"
#                     }
#                 }
#             }
#         }
#     ],
#     "xAxis": [
#         {
#             "nameLocation": "middle",
#             "min": null,
#             "nameGap": 25,
#             "name": "",

# %% [markdown]
# >+ **分类有很多种，要把菜系和食品的类别区分开（火锅可以是川菜也可以是日料，日料可以是自助也可以是海鲜）所以我们要把分类再细化，这里剔除食品分类，筛选出菜系类别（如：日料、川菜、粤菜、浙江菜、西北菜等）**

# %%
sql4 = '''select sub_id,sub_name ,count(*) as cnt from (
	select distinct a.sub_id,a.sub_name,
	b.poi_id,b.title,b.avg_price,b.avg_score,b.comment_num,b.address,b.stamp from meituan_classify_info as a
	inner join meituan_shop_info as b on a.sub_id = b.sub_id and a.class_type = b.class_type
	where a.class_type = 1 and a.sub_id in (55,56,57,58,59,60,62,227,233,20003,20059,20060)
    and b.avg_price <> 0 and b.avg_score <> 0 
) as x
group by sub_id,sub_name;
'''
df4 = pd.read_sql(sql4,conn,index_col='sub_id')
df4
# Out:
#        sub_name  cnt
# sub_id
# 55          川湘菜  793
# 56          江浙菜  650
# 57           粤菜  576
# 58          西北菜   84
# 59         京菜鲁菜   68
# 60          云贵菜   81
# 62         东南亚菜  201
# 227      台湾/客家菜   97
# 233         新疆菜   79
# 20003       东北菜  153
# 20059      日本料理  649
# 20060      韩国料理  362

# %% [markdown]
# >+ **下面就用饼图的变种南丁格尔玫瑰图皮一下，因为比较酷炫~ 但在实际应用中饼图并不能很好的诠释分类情况因为看面积有些近似的面积很难区分谁多谁少，还是柱状图来的直观**

# %%
from pyecharts import Pie

sorted_df = sorted(df4[['sub_name','cnt']].values, key=lambda x:x[1],reverse=True)
attr = [i[0] for i in sorted_df]
val = [i[1] for i in sorted_df]
    

pie = Pie("*团各大菜系店铺数", title_pos='center', width=800)

pie.add("菜系", attr, val, center=[50, 50], is_random=True,
        radius=[35,65], rosetype='radius',legend_orient='vertical',legend_pos='left',
        is_legend_show=True, is_label_show=True)
pie
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min'
#         }
#     });
# </script>
#     <div id="60c093bef49e4ad589ed4dcbb1879df7" style="width:800px;height:400px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#
# var myChart_60c093bef49e4ad589ed4dcbb1879df7 = echarts.init(document.getElementById('60c093bef49e4ad589ed4dcbb1879df7'), null, {renderer: 'canvas'});
# var option_60c093bef49e4ad589ed4dcbb1879df7 = {
#     "color": [
#         "#c23531",
#         "#546570",
#         "#749f83",
#         "#f47920",
#         "#b2d235",
#         "#ac6767",
#         "#905a3d",
#         "#6e7074",
#         "#ef5b9c",
#         "#d48265",
#         "#f05b72",
#         "#f6f5ec",
#         "#2a5caa",
#         "#bda29a",
#         "#2f4554",
#         "#444693",
#         "#61a0a8",
#         "#ca8622",
#         "#6d8346",
#         "#918597",
#         "#6950a1",
#         "#726930",
#         "#fab27b",
#         "#1d953f",
#         "#c4ccd3"
#     ],
#     "legend": [
#         {
#             "orient": "vertical",
#             "selectedMode": "multiple",
#             "top": "top",
#             "data": [
#                 "\u5ddd\u6e58\u83dc",
#                 "\u6c5f\u6d59\u83dc",
#                 "\u65e5\u672c\u6599\u7406",
#                 "\u7ca4\u83dc",
#                 "\u97e9\u56fd\u6599\u7406",
#                 "\u4e1c\u5357\u4e9a\u83dc",
#                 "\u4e1c\u5317\u83dc",
#                 "\u53f0\u6e7e/\u5ba2\u5bb6\u83dc",
#                 "\u897f\u5317\u83dc",
#                 "\u4e91\u8d35\u83dc",
#                 "\u65b0\u7586\u83dc",
#                 "\u4eac\u83dc\u9c81\u83dc"
#             ],
#             "show": true,
#             "textStyle": {
#                 "color": "#333",
#                 "fontSize": 12
#             },
#             "left": "left"
#         }
#     ],
#     "backgroundColor": "#fff",
#     "toolbox": {
#         "show": true,
#         "orient": "vertical",
#         "feature": {
#             "saveAsImage": {
#                 "show": true,
#                 "title": "\u4e0b\u8f7d\u56fe\u7247"
#             },
#             "dataView": {
#                 "show": true
#             },
#             "restore": {
#                 "show": true
#             }
#         },
#         "top": "center",
#         "left": "95%"
#     },
#     "series_id": 6142462,
#     "tooltip": {
#         "textStyle": {
#             "color": "#fff",
#             "fontSize": 14
#         },
#         "trigger": "item",
#         "borderWidth": 0,
#         "backgroundColor": "rgba(50,50,50,0.7)",
#         "axisPointer": {
#             "type": "line"
#         },
#         "triggerOn": "mousemove|click",
#         "formatter": null,
#         "borderColor": "#333"
#     },
#     "title": [
#         {
#             "subtextStyle": {
#                 "color": "#aaa",
#                 "fontSize": 12
#             },
#             "subtext": "",
#             "top": "auto",
#             "text": "*\u56e2\u5404\u5927\u83dc\u7cfb\u5e97\u94fa\u6570",
#             "textStyle": {
#                 "color": "#000",
#                 "fontSize": 18
#             },
#             "left": "center"
#         }
#     ],
#     "series": [
#         {
#             "type": "pie",
#             "label": {
#                 "normal": {
#                     "show": true,
#                     "textStyle": {
#                         "color": "#000",
#                         "fontSize": 12
#                     },
#                     "formatter": "{b}: {d}%",
#                     "position": "outside"
#                 },
#                 "emphasis": {
#                     "show": true,
#                     "textStyle": {
#                         "color": "#fff",
#                         "fontSize": 12
#                     },
#                     "position": null
#                 }
#             },
#             "seriesId": 6142462,
#             "data": [
#                 {
#                     "value": 793,
#                     "name": "\u5ddd\u6e58\u83dc"
#                 },
#                 {
#                     "value": 650,
#                     "name": "\u6c5f\u6d59\u83dc"
#                 },
#                 {
#                     "value": 649,
#                     "name": "\u65e5\u672c\u6599\u7406"
#                 },
#                 {
#                     "value": 576,
#                     "name": "\u7ca4\u83dc"
#                 },
#                 {
#                     "value": 362,
#                     "name": "\u97e9\u56fd\u6599\u7406"
#                 },
#                 {
#                     "value": 201,
#                     "name": "\u4e1c\u5357\u4e9a\u83dc"
#                 },
#                 {
#                     "value": 153,
#                     "name": "\u4e1c\u5317\u83dc"
#                 },
#                 {
#                     "value": 97,
#                     "name": "\u53f0\u6e7e/\u5ba2\u5bb6\u83dc"
#                 },
#                 {
#                     "value": 84,
#                     "name": "\u897f\u5317\u83dc"
#                 },
#                 {
#                     "value": 81,
#                     "name": "\u4e91\u8d35\u83dc"
#                 },
#                 {
#                     "value": 79,
#                     "name": "\u65b0\u7586\u83dc"
#                 },
#                 {
#                     "value": 68,
#                     "name": "\u4eac\u83dc\u9c81\u83dc"
#                 }
#             ],
#             "center": [
#                 "50%",
#                 "50%"
#             ],
#             "radius": [
#                 "35%",
#                 "65%"
#             ],
#             "roseType": "radius",
#             "name": "\u83dc\u7cfb"
#         }
#     ]
# };
# myChart_60c093bef49e4ad589ed4dcbb1879df7.setOption(option_60c093bef49e4ad589ed4dcbb1879df7);
#
#     });
# </script>

# %% [markdown]
# + **川湘菜、浙江菜、日料、粤菜、韩料 位居前5，可以说统计结果跟现实中完全吻合<br />继续对数据进行下钻，不才学过日语也了解过日本历史,所以对日料有着特别的青睐，接下来就来专门研究下日料的情况。**

# %% [markdown]
# >+ **插句题外话,若不是战争的原因日本是有着高度文明的一个国家，经常告诉自己四个字“工匠精神”，日本人捏饭团捏一辈子，凿冰凿一辈子，炸天妇罗炸一辈子，工匠们喜欢不断雕琢自己的产品，不断改善自己的工艺，享受着产品在双手中升华的过程。工匠们对细节有很高要求，追求完美和极致，对精品有着执着的坚持和追求，把品质从0提高到1，其利虽微，却长久造福于世，它是极高的职业道德、职业能力、职业品质的体现。<br /><br />ps：科普科普个小知识，IPAD大家都见过，它的研磨工艺就是出自5个人小作坊——[小林研业](http://www.360doc.com/content/18/0205/23/51477542_728005923.shtml)<br />这家为苹果研磨iPod的企业，就是位于日本新潟县燕市的“小林研业”，正是在这间其貌不扬的厂房里5名研磨技师花费了大约4年时间，为广受全球顾客欢迎的超过100万个“iPod”进行了背板的镜面加工。**

# %%
sql5 = '''select distinct a.sub_id,a.sub_name,
b.poi_id,b.title,b.avg_price,b.avg_score,b.comment_num,b.address,b.stamp from meituan_classify_info as a
inner join meituan_shop_info as b on a.sub_id = b.sub_id and a.class_type = b.class_type
where a.class_type = 1 and a.sub_id = 20059 and b.avg_price <> 0 and b.avg_score <> 0;
'''
df5 = pd.read_sql(sql5,conn,index_col='sub_id')
df5
# Out:
#        sub_name     poi_id                        title  avg_price  avg_score  \
# sub_id
# 20059      日本料理  152515863                       源季日本料理      115.0        5.0
# 20059      日本料理     466334                          京都屋       78.0        3.0
# 20059      日本料理  158829945                         牛繁烤肉      112.0        4.5
# 20059      日本料理  155992192                蟹的岡田屋（绿地缤纷城店）      530.0        4.0
# 20059      日本料理  158906789                      吉菡寿司海鲜饭       83.0        5.0
# 20059      日本料理   41409364                月岛屋大阪烧（南丹东路店）       67.0        4.8
# 20059      日本料理   65729409                     泉鲤（大悦城店）       34.0        4.7
# 20059      日本料理    6336794                    樱花いざかや居酒屋       86.0        4.0
# 20059      日本料理    4055992                         伙坊水产      499.0        5.0
# 20059      日本料理   40258031                 芥末日本料理（八佰伴店）      286.0        3.6
# 20059      日本料理  157711884            荷裕猫叔三文鱼海鲜饭（长泰广场店）       47.0        5.0
# 20059      日本料理    2571763                      米哲锅物专门店      147.0        4.4
# 20059      日本料理     475185                    御寿司（国定路店）       25.0        4.5
# 20059      日本料理  157229828                    井禾寿司（金杨店）       55.0        4.0
# 20059      日本料理    5081601                   藤幸烧肉（愚园路店）      122.0        4.2
# 20059      日本料理    1469295            知竹日式料理（恒基名人购物中心店）       41.0        3.3
# 20059      日本料理   96812271                        晶之辉和食      150.0        4.5
# 20059      日本料理  155806327              角屋北海道烧肉专门店（七宝店）       98.0        4.0
# 20059      日本料理    1592492             食特美烧肉スタミナ苑（虹梅路店）      171.0        4.2
# 20059      日本料理   41550850                  日光孙三郎（南新雅店）      248.0        4.6
# 20059      日本料理    5165639               井寿司（恒基名人购物中心店）       91.0        3.3
# 20059      日本料理  158664507                         吉頁料理      121.0        4.4
# 20059      日本料理    4204121                    锅源（新世界城店）      125.0        3.4
# 20059      日本料理   50275730                         黑方寿司       94.0        4.8
# 20059      日本料理   51091395                酷乐友居酒屋（天乐广场店）      108.0        4.0
# 20059      日本料理    5654350                    桃山日本料理铁板烧      219.0        5.0
# 20059      日本料理    4725587              上海绿地万豪酒店“红”日式料理      187.0        4.6
# 20059      日本料理    5081303                     和三昧（久光店）      422.0        4.5
# 20059      日本料理  115614784          舞泽▪雪蟹和牛蒸涮锅（七宝万科广场店）      313.0        5.0
# 20059      日本料理   41426428                  東大麺王（百联西郊店）       47.0        5.0
# ...         ...        ...                          ...        ...        ...
# 20059      日本料理   75828548                 胜世日式猪排（湖滨道店）       68.0        3.5
# 20059      日本料理     475215               缘（园）烧肉酒场（蒙自路店）      218.0        4.5
# 20059      日本料理  153727197                          竹月亭      154.0        4.5
# 20059      日本料理   50085417              渔夫铁板烧(罗宾森购物中心店)       36.0        4.0
# 20059      日本料理     395498                      柚子林炭火烧肉      252.0        4.1
# 20059      日本料理     383097                   九州拉面（沧源路店）       24.0        4.2
# 20059      日本料理     384060                        鱼鱼居酒屋      169.0        5.0
# 20059      日本料理  112522424                    喜食屋（康桥路店）       76.0        4.3
# 20059      日本料理    1473157                  朧 おぼろ OBORO      224.0        4.4
# 20059      日本料理   40690846               彩真-活鱼寿司生蚝（静安店）      230.0        5.0
# 20059      日本料理     475648                        SHARI      275.0        4.4
# 20059      日本料理   95616545            品米斗·精致料理（禹州商业广场店）      160.0        5.0
# 20059      日本料理    1587622             锦屋料理（光启城时尚购物中心店）      158.0        4.0
# 20059      日本料理   99470176                   樱粲寿司（外高桥店）       38.0        4.8
# 20059      日本料理  157801727                      心和屋烧肉餐厅      155.0        4.0
# 20059      日本料理   40100499                和禄日式料理（南汇新城店）       80.0        3.9
# 20059      日本料理    2661742                  外滩悦榕庄-酩缘中餐厅      561.0        3.5
# 20059      日本料理  102661608                          大德屋      182.0        4.0
# 20059      日本料理   42567523                         壹禾寿司       46.0        4.0
# 20059      日本料理  112588709                      竹之里日本料理      106.0        5.0
# 20059      日本料理    1602434                       岩屋日本料理      131.0        4.4
# 20059      日本料理     440630                   寿司王子（八佰伴店）       80.0        4.2
# 20059      日本料理   66777484                    龍馬烧肉（淮海店）      177.0        3.5
# 20059      日本料理  150644267                          粋寿司       85.0        4.0
# 20059      日本料理     482260                   末那寿司（玫瑰坊店）       88.0        4.7
# 20059      日本料理  114412617                牛小新烧肉屋（淮海中路店）      120.0        5.0
# 20059      日本料理   42142555                       卷 日本料理       86.0        3.8
# 20059      日本料理   93203901           泉之隐日式家庭料理居酒屋（五角场店）      106.0        4.5
# 20059      日本料理  105064580  鲑觅日本料理Shake Kakei（日月光中心广场店）      129.0        4.1
# 20059      日本料理   88859843             骏甲屋の夜桜（田尚坊商业中心店）      186.0        3.8
#
#         comment_num                                            address  \
# sub_id
# 20059            93                                        虹口区东宝兴路118号
# 20059             0                                  黄浦区广西北路256号（近汉口路）
# 20059             4                    宝山区大华路大华一路大华虎城嘉年华B1楼352号B1楼108室
# 20059            10  徐汇区瑞平路88号绿地缤纷城1层W-D106、107（地铁龙华中路站5、6、7号出口，靠近东安路）
# 20059           219                           卢湾区泰康路248弄21号（田子坊二号门弄堂内）
# 20059           117                              徐汇区南丹东路111号-5（徐汇区图书馆）
# 20059            46                              闸北区西藏北路198号上海大悦城北座B1室
# 20059           288                   浦东新区浦东南路2141弄4号(近浦澳路（浦东南路浦澳路路口）)
# 20059             4                          长宁区延安西路688弄2号华敏翰尊旁边（近江苏路）
# 20059           325                              浦东新区东方路778号（紫金山大酒店2楼）
# 20059            72                           浦东新区金科路2889号长泰广场东区1层蓝蛙对面
# 20059           392                      徐汇区天钥桥路333号腾飞大厦207室（上海体育场地铁站）
# 20059            37                         杨浦区国定路600弄40-1号（406公交站总站旁）
# 20059            11                                        浦东新区金杨路516号
# 20059           285                          静安区愚园路96号108美食广场3楼3号（胶州路）
# 20059          1620                             黄浦区南京东路300号恒基名人购物中心B1层
# 20059             4                          闸北区共和路209号嘉里不夜城企业中心2座102室
# 20059            22                    闵行区沪星路105号车配龙生活欢乐港1楼（凯德家乐福停车场旁）
# 20059             8                                  闵行区虹梅路3211号泰豪大厦3楼
# 20059           635                        黄浦区九江路700号南新雅大酒店2楼（南京东路步行街）
# 20059          1628             黄浦区南京东路300号恒基名人购物中心4层L423-24（近南京东路地铁站）
# 20059            24                               闵行区七莘路695号乐购购物中心广场一楼
# 20059          1423                                 黄浦区南京西路2-68号新世界城9层
# 20059            50                                  静安区茂名北路80号（近延安中路）
# 20059             2                                 闵行区银亭路68-78号天乐广场3层
# 20059           574                     浦东新区商城路618号良友大厦28楼（近9号线2号口出口处）
# 20059            13                                 浦东新区江滨路99号绿地万豪酒店2楼
# 20059             6                           静安区南京西路1618号久光百货9楼（近华山路）
# 20059           419                           闵行区漕宝路3366号七宝万科广场1层138铺位
# 20059          1056                           闵行区仙霞西路88号百联西郊B101（麦当劳旁）
# ...             ...                                                ...
# 20059             3                               黄浦区湖滨路150号湖滨道购物中心B2层
# 20059            29                             卢湾区蒙自路207号（宏慧盟智园，近丽园路）
# 20059             5                 长宁区地铁3、4号线虹桥路站1号出口（地铁3、4号线虹桥路站1号口）
# 20059           189                                嘉定区城中路138号罗宾森购物中心1层
# 20059            13                            浦东新区潍坊路328号嘉瑞酒店1楼(近源深路)
# 20059           405                               闵行区沧源路839号（近东川路闵行交大）
# 20059           463                          闵行区吴中路1099号吴中商务大厦1楼（近万源路）
# 20059           183                 浦东新区康桥路1157号5栋1106号（康桥路御青路交叉口北50米）
# 20059            29                                  静安区常熟路83号4楼(近巨鹿路)
# 20059           684                                静安区愚园路96号3F-1（近胶州路）
# 20059           150          徐汇区永嘉路630号（近乌鲁木齐南路,地铁1号线衡山路站1号口出来步行约520米）
# 20059           315                              浦东新区沪南公路9928号禹州商业广场3层
# 20059          2400                            徐汇区宜山路455号光启城时尚购物中心B区4层
# 20059            47                             浦东新区张杨北路清溪路路口小马宝莉美食城2层
# 20059             3                                       徐汇区南丹东路111-6
# 20059           163                        浦东新区南汇新城山兰路步行街480号（临港新城地铁站）
# 20059             0                         虹口区海平路19号上海外滩悦榕庄酒店2楼（公平路口）
# 20059             0                                     静安区泰兴路89号裸心社2楼
# 20059             8                                  闸北区芷江西路243号（共和新路）
# 20059           745             闸北区阳城路420号（沪太支路，七号线行知路1号出口，浦联佳苑小区可以停车）
# 20059          1295                                   松江区普照路54号（近松汇中路）
# 20059          1900                          浦东新区南泉北路528号新大陆广场北楼2层205室
# 20059           787                           黄浦区淮海中路1号H1美食不夜城2F（西藏南路）
# 20059            64                      杨浦区殷行路1388号上海悠方L140（两栋大楼中间通道）
# 20059           238            长宁区长宁路890号玫瑰坊商场2楼88号（地铁2号线3号口，汇川路龙之梦对面）
# 20059          2499                  黄浦区淮海中路755号淮海755四楼（瑞金二路路口，无印良品楼上）
# 20059            90                                  静安区武定路1073号（近胶州路）
# 20059            21                                  杨浦区国权东路154号（近关山路）
# 20059            21                     卢湾区徐家汇路618号日月光中心广场2楼徐家汇区04-06号
# 20059             9                    徐汇区钦州北路226号田尚坊商业中心B1（金茂传菜旁楼梯下面）
#
#                      stamp
# sub_id
# 20059  2018-04-06 21:57:36
# 20059  2018-04-06 21:54:52
# 20059  2018-04-05 17:35:54
# 20059  2018-04-06 21:57:49
# 20059  2018-04-06 21:58:21
# 20059  2018-04-06 21:51:51
# 20059  2018-04-06 21:55:34
# 20059  2018-04-05 17:34:41
# 20059  2018-04-06 21:54:23
# 20059  2018-04-05 17:34:44
# 20059  2018-04-06 21:58:03
# 20059  2018-04-06 21:52:14
# 20059  2018-04-05 17:34:41
# 20059  2018-04-05 17:35:52
# 20059  2018-04-06 21:51:31
# 20059  2018-04-06 21:52:41
# 20059  2018-04-05 17:35:34
# 20059  2018-04-05 17:35:49
# 20059  2018-04-06 21:54:57
# 20059  2018-04-06 21:55:17
# 20059  2018-04-06 21:52:44
# 20059  2018-04-05 17:35:54
# 20059  2018-04-06 21:52:20
# 20059  2018-04-06 21:53:56
# 20059  2018-04-05 17:35:22
# 20059  2018-04-06 21:52:13
# 20059  2018-04-05 17:35:17
# 20059  2018-04-06 21:55:05
# 20059  2018-04-06 21:57:08
# 20059  2018-04-06 21:51:54
# ...                    ...
# 20059  2018-04-05 17:35:26
# 20059  2018-04-05 17:35:00
# 20059  2018-04-05 17:35:49
# 20059  2018-04-06 21:53:16
# 20059  2018-04-06 21:54:43
# 20059  2018-04-06 21:52:59
# 20059  2018-04-06 21:52:10
# 20059  2018-04-06 21:57:06
# 20059  2018-04-06 21:54:55
# 20059  2018-04-06 21:53:11
# 20059  2018-04-06 21:53:05
# 20059  2018-04-06 21:56:34
# 20059  2018-04-05 17:34:41
# 20059  2018-04-06 21:56:50
# 20059  2018-04-05 17:35:53
# 20059  2018-04-06 21:51:37
# 20059  2018-04-05 17:35:16
# 20059  2018-04-05 17:35:37
# 20059  2018-04-05 17:35:22
# 20059  2018-04-05 17:35:41
# 20059  2018-04-06 21:51:28
# 20059  2018-04-06 21:51:43
# 20059  2018-04-06 21:54:38
# 20059  2018-04-06 21:57:30
# 20059  2018-04-06 21:53:57
# 20059  2018-04-06 21:57:07
# 20059  2018-04-06 21:54:07
# 20059  2018-04-06 21:56:26
# 20059  2018-04-06 21:56:55
# 20059  2018-04-06 21:55:52
#
# [649 rows x 8 columns]
