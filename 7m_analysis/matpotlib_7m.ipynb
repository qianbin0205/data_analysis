# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
# %matplotlib inline

# %%
fig,axes = plt.subplots(figsize=(10,6),nrows= 2, ncols=2)

# %%
ax1 = fig.add_subplot(2,2,1)
ax1.plot(np.random.random(50).cumsum(),'k--')

ax2 = fig.add_subplot(2,2,2)
ax2.scatter(np.arange(30),np.arange(30)+3*np.random.random(30))

ax3 = fig.add_subplot(2,1,2)
ax3.hist(np.random.random(50),bins=20,color='r',alpha=0.3)

fig

# %%
#概率分布直方图  
#高斯分布  
#均值为0  
mean = 0  
#标准差为1，反应数据集中还是分散的值  
sigma = 1  
x=mean+sigma*np.random.randn(10000)  
fig,(ax0,ax1) = plt.subplots(nrows=2,figsize=(10,6))  
#第二个参数是柱子宽一些还是窄一些，越大越窄越密  
ax0.hist(x,40,normed=1,histtype='bar',facecolor='yellowgreen',alpha=0.75)  
##pdf概率分布图，一万个数落在某个区间内的数有多少个  
ax0.set_title('pdf')  
ax1.hist(x,50,normed=1,histtype='bar',facecolor='pink',alpha=0.75,cumulative=True,rwidth=0.8)  
#cdf累计概率函数，cumulative累计。比如需要统计小于5的数的概率  
ax1.set_title("cdf")  
fig.subplots_adjust(hspace= 0.3)

# %%
fig, axes = plt.subplots(nrows= 2, ncols=2,figsize=(10,6)
                         ,sharex=True,sharey=True
                        ) 
plt.subplots_adjust(left=None, bottom=None, right=None, top=None, wspace=0, hspace=0)

# %%
axes
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000016DEE0ADEB8>,
# ...
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000016DEE37B8D0>]], dtype=object)

# %%
axes[1,1]

# %%
for i in axes:
    for ii in i:
        ii.hist(np.random.randn(1000),50,color='r',alpha=0.75)
fig

# %%
plt.close('all')

# %%
plt.figure(figsize=(16,10))
data = np.random.randn(50)
plt.plot(data,'k--',label='Defult',c='r')
plt.plot(data,'k-',label='Steps',drawstyle='steps-post')
plt.legend(['Defult','Steps'],loc='best')

# %%
data = pd.Series(np.random.rand(4),index=list('abcd'))

# %%
fig, axes = plt.subplots(nrows= 2, ncols=1, figsize=(10,6))
data.plot(kind='barh',ax = axes[0])
data.plot(kind='bar',ax = axes[1])

# %%
df_data2 = pd.DataFrame(np.random.rand(6,4),
                     index=['one','two','tree','four','five','six'],
                     columns=pd.Index(['A','B','C','D'],name='Genus')
                    )
df_data2
# Out:
# Genus         A         B         C         D
# one    0.590194  0.333877  0.614513  0.893357
# two    0.086958  0.646584  0.380244  0.276851
# tree   0.334479  0.088192  0.540860  0.152277
# four   0.533856  0.551468  0.222923  0.028075
# five   0.327793  0.087629  0.850349  0.838541
# six    0.916242  0.566792  0.887877  0.293998

# %%
df_data2.plot(figsize=(10,6),kind='barh',stacked=True,alpha=0.75)

# %%
tips = pd.read_csv('./tips.csv')
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
party_counts = pd.crosstab(tips.day, tips.size)
party_counts
# Out:
# col_0  1708
# day
# Fri      19
# Sat      87
# Sun      76
# Thur     62
